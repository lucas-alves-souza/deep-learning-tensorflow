# %%
import pandas as pd
base = pd.read_csv('census.csv')
base.head()
# Out:
#    age          workclass  final-weight  ... hour-per-week  native-country  income
# 0   39          State-gov         77516  ...            40   United-States   <=50K
# 1   50   Self-emp-not-inc         83311  ...            13   United-States   <=50K
# 2   38            Private        215646  ...            40   United-States   <=50K
# 3   53            Private        234721  ...            40   United-States   <=50K
# 4   28            Private        338409  ...            40            Cuba   <=50K
#
# [5 rows x 15 columns]

# %%
base.income.unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
def converte_classe(rotulo):
    if rotulo == ' >50K':
        return 1
    else:
        return 0

# %%
base.income = base.income.apply(converte_classe)

# %%
base.head()
# Out:
#    age          workclass  final-weight  ... hour-per-week  native-country income
# 0   39          State-gov         77516  ...            40   United-States      0
# 1   50   Self-emp-not-inc         83311  ...            13   United-States      0
# 2   38            Private        215646  ...            40   United-States      0
# 3   53            Private        234721  ...            40   United-States      0
# 4   28            Private        338409  ...            40            Cuba      0
#
# [5 rows x 15 columns]

# %%
X = base.drop('income', axis = 1)
y = base.income

# %%
X.head()
# Out:
#    age          workclass  ...  hour-per-week  native-country
# 0   39          State-gov  ...             40   United-States
# 1   50   Self-emp-not-inc  ...             13   United-States
# 2   38            Private  ...             40   United-States
# 3   53            Private  ...             40   United-States
# 4   28            Private  ...             40            Cuba
#
# [5 rows x 14 columns]

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: income, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
X_treinamento.shape
# Out:
# (22792, 14)

# %%
X_teste.shape
# Out:
# (9769, 14)

# %%
base.columns
# Out:
# Index(['age', 'workclass', 'final-weight', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loos', 'hour-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.3.0'

# %%
base.workclass.unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
workclass = tf.feature_column.categorical_column_with_hash_bucket(key = 'workclass', hash_bucket_size = 100)
education = tf.feature_column.categorical_column_with_hash_bucket(key = 'education', hash_bucket_size = 100)
marital_status = tf.feature_column.categorical_column_with_hash_bucket(key = 'marital-status', hash_bucket_size = 100)
occupation = tf.feature_column.categorical_column_with_hash_bucket(key = 'occupation', hash_bucket_size = 100)
relationship = tf.feature_column.categorical_column_with_hash_bucket(key = 'relationship', hash_bucket_size = 100)
race = tf.feature_column.categorical_column_with_hash_bucket(key = 'race', hash_bucket_size = 100)
country = tf.feature_column.categorical_column_with_hash_bucket(key = 'native-country', hash_bucket_size = 100)

# %%
base.sex.unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
sex = tf.feature_column.categorical_column_with_vocabulary_list(key = 'sex', vocabulary_list=[' Male', ' Female'])

# %%
base.age.mean()
# Out:
# 38.58164675532078

# %%
base.age.std()
# Out:
# 13.640432553581146

# %%
def padroniza_age(valor):
    return tf.divide(tf.subtract(tf.cast(valor, tf.float32), tf.constant(38.58)), tf.constant(13.64))

def padroniza_finalweight(valor):
    return tf.divide(tf.subtract(tf.cast(valor, tf.float32), tf.constant(189778.36)), tf.constant(105549.977))

def padroniza_education(valor):
    return tf.divide(tf.subtract(tf.cast(valor, tf.float32), tf.constant(10.08)), tf.constant(2.57))

def padroniza_capitalgain(valor):
    return tf.divide(tf.subtract(tf.cast(valor, tf.float32), tf.constant(1077.64)), tf.constant(7385.29))

def padroniza_capitalloos(valor):
    return tf.divide(tf.subtract(tf.cast(valor, tf.float32), tf.constant(87.30)), tf.constant(402.96))

def padroniza_hour(valor):
    return tf.divide(tf.subtract(tf.cast(valor, tf.float32), tf.constant(40.43)), tf.constant(12.34))

# %%
age = tf.feature_column.numeric_column(key = 'age', normalizer_fn = padroniza_age)
final_weight = tf.feature_column.numeric_column(key = 'final-weight', normalizer_fn = padroniza_finalweight)
education_num = tf.feature_column.numeric_column(key = 'education-num', normalizer_fn = padroniza_education)
capital_gain = tf.feature_column.numeric_column(key = 'capital-gain', normalizer_fn = padroniza_capitalgain)
capital_loos = tf.feature_column.numeric_column(key = 'capital-loos', normalizer_fn = padroniza_capitalloos)
hour = tf.feature_column.numeric_column(key = 'hour-per-week', normalizer_fn = padroniza_hour)

# %%
len(base.workclass.unique())
# Out:
# 9

# %%
embedded_workclass = tf.feature_column.embedding_column(workclass, dimension = 9)
embedded_education = tf.feature_column.embedding_column(education, dimension = len(base.education.unique()))
embedded_marital = tf.feature_column.embedding_column(marital_status, dimension = len(base['marital-status'].unique()))
embedded_occupation = tf.feature_column.embedding_column(occupation, dimension = len(base.occupation.unique()))
embedded_relationship = tf.feature_column.embedding_column(relationship, dimension = len(base.relationship.unique()))
embedded_race = tf.feature_column.embedding_column(race, dimension = len(base.race.unique()))
embedded_sex = tf.feature_column.embedding_column(sex, dimension = len(base.sex.unique()))
embedded_country = tf.feature_column.embedding_column(country, dimension = len(base['native-country'].unique()))

# %%
colunas_rna = [age, embedded_workclass, final_weight, embedded_education, education_num,
               embedded_marital, embedded_occupation, embedded_relationship, 
               embedded_race, embedded_sex,
               capital_gain, capital_loos, hour, embedded_country]

# %%
def make_input_fn(X, y = None, num_epochs = None, shuffle = True, batch_size=32):
    def input_function():
        ds = tf.data.Dataset.from_tensor_slices((dict(X), y))
        if shuffle:
            ds = ds.shuffle(1000)
        ds = ds.batch(batch_size).repeat(num_epochs)
        return ds
    return input_function

# %%
funcao_treinamento = make_input_fn(X_treinamento, y_treinamento)

# %%
config = tf.estimator.RunConfig(tf_random_seed = 42)
classificador = tf.estimator.DNNClassifier(hidden_units = [8, 8], feature_columns = colunas_rna, n_classes = 2, config = config)
classificador.train(input_fn = funcao_treinamento, steps = 10000)
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp4d8wm56v
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmp4d8wm56v', '_tf_random_seed': 42, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/optimizer_v2/adagrad.py:83: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmp4d8wm56v/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 0.67846966, step = 0
# INFO:tensorflow:global_step/sec: 198.039
# INFO:tensorflow:loss = 0.641011, step = 100 (0.506 sec)
# INFO:tensorflow:global_step/sec: 404.741
# INFO:tensorflow:loss = 0.61818624, step = 200 (0.248 sec)
# INFO:tensorflow:global_step/sec: 396.526
# INFO:tensorflow:loss = 0.6073266, step = 300 (0.252 sec)
# INFO:tensorflow:global_step/sec: 420.617
# INFO:tensorflow:loss = 0.5919659, step = 400 (0.238 sec)
# INFO:tensorflow:global_step/sec: 396.592
# INFO:tensorflow:loss = 0.6071208, step = 500 (0.252 sec)
# INFO:tensorflow:global_step/sec: 467.839
# INFO:tensorflow:loss = 0.61996543, step = 600 (0.214 sec)
# INFO:tensorflow:global_step/sec: 429.787
# INFO:tensorflow:loss = 0.6287213, step = 700 (0.233 sec)
# INFO:tensorflow:global_step/sec: 446.765
# INFO:tensorflow:loss = 0.592767, step = 800 (0.226 sec)
# INFO:tensorflow:global_step/sec: 410.211
# INFO:tensorflow:loss = 0.5473638, step = 900 (0.244 sec)
# INFO:tensorflow:global_step/sec: 454.325
# INFO:tensorflow:loss = 0.53446496, step = 1000 (0.218 sec)
# INFO:tensorflow:global_step/sec: 433.017
# INFO:tensorflow:loss = 0.44462252, step = 1100 (0.231 sec)
# INFO:tensorflow:global_step/sec: 482.986
# INFO:tensorflow:loss = 0.53108656, step = 1200 (0.207 sec)
# INFO:tensorflow:global_step/sec: 488.687
# INFO:tensorflow:loss = 0.5668388, step = 1300 (0.205 sec)
# INFO:tensorflow:global_step/sec:
 (0.209 sec)
# INFO:tensorflow:global_step/sec: 479.826
# INFO:tensorflow:loss = 0.33046064, step = 7900 (0.208 sec)
# INFO:tensorflow:global_step/sec: 472.11
# INFO:tensorflow:loss = 0.42803672, step = 8000 (0.212 sec)
# INFO:tensorflow:global_step/sec: 472.386
# INFO:tensorflow:loss = 0.5073464, step = 8100 (0.212 sec)
# INFO:tensorflow:global_step/sec: 474.865
# INFO:tensorflow:loss = 0.4039416, step = 8200 (0.210 sec)
# INFO:tensorflow:global_step/sec: 514.63
# INFO:tensorflow:loss = 0.41526383, step = 8300 (0.194 sec)
# INFO:tensorflow:global_step/sec: 442.045
# INFO:tensorflow:loss = 0.37339377, step = 8400 (0.226 sec)
# INFO:tensorflow:global_step/sec: 495.116
# INFO:tensorflow:loss = 0.4203329, step = 8500 (0.203 sec)
# INFO:tensorflow:global_step/sec: 402.942
# INFO:tensorflow:loss = 0.35299906, step = 8600 (0.248 sec)
# INFO:tensorflow:global_step/sec: 465.007
# INFO:tensorflow:loss = 0.2604047, step = 8700 (0.215 sec)
# INFO:tensorflow:global_step/sec: 490.507
# INFO:tensorflow:loss = 0.42295134, step = 8800 (0.204 sec)
# INFO:tensorflow:global_step/sec: 502.152
# INFO:tensorflow:loss = 0.39478847, step = 8900 (0.199 sec)
# INFO:tensorflow:global_step/sec: 459.283
# INFO:tensorflow:loss = 0.39967364, step = 9000 (0.218 sec)
# INFO:tensorflow:global_step/sec: 448.303
# INFO:tensorflow:loss = 0.41936785, step = 9100 (0.223 sec)
# INFO:tensorflow:global_step/sec: 467.571
# INFO:tensorflow:loss = 0.42750365, step = 9200 (0.215 sec)
# INFO:tensorflow:global_step/sec: 476.021
# INFO:tensorflow:loss = 0.41738892, step = 9300 (0.209 sec)
# INFO:tensorflow:global_step/sec: 488.359
# INFO:tensorflow:loss = 0.39889488, step = 9400 (0.205 sec)
# INFO:tensorflow:global_step/sec: 463.339
# INFO:tensorflow:loss = 0.36938578, step = 9500 (0.216 sec)
# INFO:tensorflow:global_step/sec: 445.534
# INFO:tensorflow:loss = 0.4033914, step = 9600 (0.224 sec)
# INFO:tensorflow:global_step/sec: 473.262
# INFO:tensorflow:loss = 0.31910425, step = 9700 (0.215 sec)
# INFO:tensorflow:global_step/sec: 481.916
# INFO:tensorflow:loss = 0.35154885, step = 9800 (0.207 sec)
# INFO:tensorflow:global_step/sec: 435.316
# INFO:tensorflow:loss = 0.36600888, step = 9900 (0.226 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 10000...
# INFO:tensorflow:Saving checkpoints for 10000 into /tmp/tmp4d8wm56v/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 10000...
# INFO:tensorflow:Loss for final step: 0.61470175.

# %%
funcao_teste = make_input_fn(X_teste, y_teste, num_epochs = 1, shuffle = False)

# %%
classificador.evaluate(input_fn = funcao_teste, steps = 10000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-09-04T22:08:23Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp4d8wm56v/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 1.47886s
# INFO:tensorflow:Finished evaluation at 2020-09-04-22:08:24
# INFO:tensorflow:Saving dict for global step 10000: accuracy = 0.82249975, accuracy_baseline = 0.7631283, auc = 0.86699, auc_precision_recall = 0.65954363, average_loss = 0.380941, global_step = 10000, label/mean = 0.23687173, loss = 0.38081694, precision = 0.67967784, prediction/mean = 0.24519, recall = 0.47407088
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10000: /tmp/tmp4d8wm56v/model.ckpt-10000
# {'accuracy': 0.82249975,
#  'accuracy_baseline': 0.7631283,
#  'auc': 0.86699,
#  'auc_precision_recall': 0.65954363,
#  'average_loss': 0.380941,
#  'global_step': 10000,
#  'label/mean': 0.23687173,
#  'loss': 0.38081694,
#  'precision': 0.67967784,
#  'prediction/mean': 0.24519,
#  'recall': 0.47407088}

# %% [markdown]
# https://towardsdatascience.com/how-to-normalize-features-in-tensorflow-5b7b0e3a4177
